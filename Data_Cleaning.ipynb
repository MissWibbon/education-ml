# %%
import pandas as pd

# %% [markdown]
# # Column Name Descriptions
# INSTNM (Institution Name)
# SATBBR (State Abbreviation)
# City
# Latitude
# Longitude
# SCHTYPE (1=Public, 2=Private,non-profit)
# C100_4_POOLED (completion rate for 4 year institutions)
# TRANS_4_POOLED (Transfer rate for first-time, full-time students at four-year institutions)
# SAT_AVG (SAT average score)
# ACTCMMID (ACT composite midpoint score)
# UGDS_WHITE (Total share of enrollment of undergraduate degree-seeking students who are white)
# UGDS_BLACK (Total share of enrollment of undergraduate degree-seeking students who are Black)
# UGDS_HISP (Total share of enrollment of undergraduate degree-seeking students who are Hispanic)
# UGDS_ASIAN (Total share of enrollment of undergraduate degree-seeking students who are Asian)

# %%
SY19 = pd.read_csv("MERGED2018_19_PP.csv")
# SY19.IL()
SY19_IL = SY19.loc[SY19["STABBR"]=="IL"]
# SY19_IL.head()
SY19_IL = SY19_IL[["INSTNM","STABBR","CITY","LATITUDE","LONGITUDE","SCHTYPE","C100_4_POOLED","TRANS_4_POOLED","SAT_AVG","ACTCMMID","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN"]]
# SY19_IL.head()
SY19_IL = SY19_IL.dropna(subset=["C100_4_POOLED","SAT_AVG","ACTCMMID"])
SY19_IL
# Out:
#                                           INSTNM STABBR           CITY  \
# 865       School of the Art Institute of Chicago     IL        Chicago
# 867                            Aurora University     IL         Aurora
# 872                            Blackburn College     IL    Carlinville
# 875                           Bradley University     IL         Peoria
# 888                     Chicago State University     IL        Chicago
# 890                        University of Chicago     IL        Chicago
# 899                 Concordia University-Chicago     IL   River Forest
# 907                  Eastern Illinois University     IL     Charleston
# 909                             Elmhurst College     IL       Elmhurst
# 910                               Eureka College     IL         Eureka
# 917                        Greenville University     IL     Greenville
# 921                   Hebrew Theological College     IL         Skokie
# ...

# %%
SY18 = pd.read_csv("MERGED2017_18_PP.csv")
# SY18.head()
SY18_IL = SY18.loc[SY18["STABBR"]=="IL"]
# SY18_IL.head()
SY18_IL = SY18_IL[["INSTNM","LATITUDE","LONGITUDE","SCHTYPE","C100_4_POOLED","TRANS_4_POOLED","SAT_AVG","ACTCMMID","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN"]]
# SY18_IL.head()
SY18_IL = SY18_IL.dropna(subset=["SAT_AVG","ACTCMMID"])
SY18_IL
# Out:
#                                           INSTNM  LATITUDE  LONGITUDE  \
# 904       School of the Art Institute of Chicago       NaN        NaN
# 906                            Aurora University       NaN        NaN
# 911                            Blackburn College       NaN        NaN
# 914                           Bradley University       NaN        NaN
# 928                     Chicago State University       NaN        NaN
# 930                        University of Chicago       NaN        NaN
# 939                 Concordia University-Chicago       NaN        NaN
# 946                         East-West University       NaN        NaN
# 947                  Eastern Illinois University       NaN        NaN
# 949                             Elmhurst College       NaN        NaN
# 950                               Eureka College       NaN        NaN
# 955                   Governors State University       NaN        NaN
# ...

# %%
SY17 = pd.read_csv("MERGED2016_17_PP.csv")
# SY17.head()
SY17_IL = SY17.loc[SY17["STABBR"]=="IL"]
# SY17_IL.head()
SY17_IL = SY17_IL[["INSTNM","LATITUDE","LONGITUDE","SCHTYPE","C100_4_POOLED","TRANS_4_POOLED","SAT_AVG","ACTCMMID","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN"]]
# SY17_IL.head()
SY17_IL = SY17_IL.dropna(subset=["SAT_AVG","ACTCMMID"])
SY17_IL
# Out:
#                                           INSTNM  LATITUDE  LONGITUDE  \
# 923       School of the Art Institute of Chicago       NaN        NaN
# 925                            Aurora University       NaN        NaN
# 930                            Blackburn College       NaN        NaN
# 933                           Bradley University       NaN        NaN
# 947                     Chicago State University       NaN        NaN
# 949                        University of Chicago       NaN        NaN
# 958                 Concordia University-Chicago       NaN        NaN
# 967                  Eastern Illinois University       NaN        NaN
# 969                             Elmhurst College       NaN        NaN
# 970                               Eureka College       NaN        NaN
# 975                   Governors State University       NaN        NaN
# 977                        Greenville University       NaN        NaN
# ...

# %%
SY16 = pd.read_csv("MERGED2015_16_PP.csv")
# SY16.head()
SY16_IL = SY16.loc[SY16["STABBR"]=="IL"]
# SY16_IL.head()
SY16_IL = SY16_IL[["INSTNM","LATITUDE","LONGITUDE","SCHTYPE","C100_4_POOLED","TRANS_4_POOLED","SAT_AVG","ACTCMMID","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN"]]
# SY16_IL.head()
SY16_IL = SY16_IL.dropna(subset=["SAT_AVG","ACTCMMID"])
SY16_IL
# Out:
#                                           INSTNM  LATITUDE  LONGITUDE  \
# 950       School of the Art Institute of Chicago       NaN        NaN
# 952                            Aurora University       NaN        NaN
# 957                            Blackburn College       NaN        NaN
# 960                           Bradley University       NaN        NaN
# 974                     Chicago State University       NaN        NaN
# 976                        University of Chicago       NaN        NaN
# 985                 Concordia University-Chicago       NaN        NaN
# 994                  Eastern Illinois University       NaN        NaN
# 996                             Elmhurst College       NaN        NaN
# 997                               Eureka College       NaN        NaN
# 1002                  Governors State University       NaN        NaN
# 1004                       Greenville University       NaN        NaN
# ...

# %%
SY15 = pd.read_csv("MERGED2014_15_PP.csv")
# SY15.head()
SY15_IL = SY15.loc[SY15["STABBR"]=="IL"]
# SY15_IL.head()
SY15_IL = SY15_IL[["INSTNM","LATITUDE","LONGITUDE","SCHTYPE","C100_4_POOLED","TRANS_4_POOLED","SAT_AVG","ACTCMMID","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN"]]
# SY15_IL.head()
SY15_IL = SY15_IL.dropna(subset=["SAT_AVG","ACTCMMID"])
SY15_IL
# Out:
#                                           INSTNM  LATITUDE  LONGITUDE  \
# 995       School of the Art Institute of Chicago       NaN        NaN
# 997                            Aurora University       NaN        NaN
# 1002                           Blackburn College       NaN        NaN
# 1005                          Bradley University       NaN        NaN
# 1019                    Chicago State University       NaN        NaN
# 1021                       University of Chicago       NaN        NaN
# 1030                Concordia University-Chicago       NaN        NaN
# 1039                 Eastern Illinois University       NaN        NaN
# 1041                            Elmhurst College       NaN        NaN
# 1042                              Eureka College       NaN        NaN
# 1047                  Governors State University       NaN        NaN
# 1048           Graham Hospital School of Nursing       NaN        NaN
# ...

# %%
print(f'The length of SY15_IL is {len(SY15_IL)}')
print(f'The length of SY16_IL is {len(SY16_IL)}')
print(f'The length of SY17_IL is {len(SY17_IL)}')
print(f'The length of SY18_IL is {len(SY18_IL)}')
print(f'The length of SY19_IL is {len(SY19_IL)}')
# Out:
# The length of SY15_IL is 51
# The length of SY16_IL is 50
# The length of SY17_IL is 50
# The length of SY18_IL is 52
# The length of SY19_IL is 49
