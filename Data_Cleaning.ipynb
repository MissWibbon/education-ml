# %%
import pandas as pd

# %% [markdown]
# # Column Name Descriptions
# INSTNM (Institution Name)
# SATBBR (State Abbreviation)
# City
# Latitude
# Longitude
# SCHTYPE (0=Public, 1=Private,non-profit)
# C100_4 (completion rate for 4 year institutions)
# TRANS_4 (Transfer rate for first-time, full-time students at four-year institutions)
# SAT_AVG (SAT average score)
# ACTCMMID (ACT composite midpoint score)
# UGDS_WOMEN (Number of Women)
# UGDS_MEN (Number of Men)
# UGDS_WHITE (Total share of enrollment of undergraduate degree-seeking students who are white)
# UGDS_BLACK (Total share of enrollment of undergraduate degree-seeking students who are Black)
# UGDS_HISP (Total share of enrollment of undergraduate degree-seeking students who are Hispanic)
# UGDS_ASIAN (Total share of enrollment of undergraduate degree-seeking students who are Asian)
# TUITIONFEE_IN (In-state tuition and fees)
# TUITIONFEE_OUT (Out-of-state tuition and fees)
# COSTT4_A (Average cost of attendance (academic year institutions))

# %%
SY19 = pd.read_csv("MERGED2018_19_PP.csv")
# SY19.IL()
SY19_IL = SY19.loc[SY19["STABBR"]=="IL"]
# SY19_IL.head()

SY19_IL = SY19_IL[["INSTNM","STABBR","CITY","LATITUDE","LONGITUDE","SCHTYPE","C100_4","TRANS_4","SAT_AVG","ACTCMMID","UGDS","UGDS_WOMEN","UGDS_MEN","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN","TUITIONFEE_IN","TUITIONFEE_OUT","COSTT4_A"]]
SY19_IL = SY19_IL.dropna()

SY19_IL["SCHTYPE"] = SY19_IL["SCHTYPE"].replace(1,0)
SY19_IL["SCHTYPE"] = SY19_IL["SCHTYPE"].replace(2,1)
SY19_IL["SCHTYPE"] = SY19_IL["SCHTYPE"].replace(3,1)

SY19_IL.head()
# Out:
# C:\Users\koros\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (9,1725,1726,1727,1728,1729,1743,1815,1816,1817,1818,1823,1824,1830,1831,1879,1880,1881,1882,1883,1884,1885,1886,1887,1888,1889,1890,1891,1892,1893,1894,1895,1896,1897,1898,1909,1910,1911,1912,1913,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1983,1984) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                      INSTNM STABBR         CITY   LATITUDE  \
# 865  School of the Art Institute of Chicago     IL      Chicago  41.881050
# 867                       Aurora University     IL       Aurora  41.753631
# 872                       Blackburn College     IL  Carlinville  39.287896
# 875                      Bradley University     IL       Peoria  40.696896
# ...

# %%
SY18 = pd.read_csv("MERGED2017_18_PP.csv")
# SY18.head()
SY18_IL = SY18.loc[SY18["STABBR"]=="IL"]
# SY18_IL.head()
SY18_IL = SY18_IL[["INSTNM","STABBR","CITY","LATITUDE","LONGITUDE","SCHTYPE","C100_4","TRANS_4","SAT_AVG","ACTCMMID","UGDS","UGDS_WOMEN","UGDS_MEN","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN","TUITIONFEE_IN","TUITIONFEE_OUT","COSTT4_A"]]
SY18_IL["Year"]="2018"
SY18_IL
# Out:
# C:\Users\koros\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (1729) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                             INSTNM STABBR         CITY  \
# 901                               Adler University     IL      Chicago
# 902                        American Academy of Art     IL      Chicago
# 903                       American Islamic College     IL      Chicago
# 904         School of the Art Institute of Chicago     IL      Chicago
# 905                              Augustana College     IL  Rock Island
# ...                                            ...    ...          ...
# 6875              Lindenwood University-Belleville     IL   Belleville
# 7029                      Rasmussen College-Aurora     IL       Aurora
# ...

# %%
for index, row in SY18_IL.iterrows():
    if row['INSTNM'] in SY19_IL['INSTNM'].tolist():
        latitude = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'LATITUDE'].iloc[0]
        SY18_IL.at[index,'LATITUDE']= latitude
        longitude = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'LONGITUDE'].iloc[0]
        SY18_IL.at[index,'LONGITUDE']= longitude
        school_type = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'SCHTYPE'].iloc[0]
        SY18_IL.at[index,'SCHTYPE']= school_type
        
SY18_IL = SY18_IL.dropna()
SY18_IL.head()
# Out:
#                                      INSTNM STABBR         CITY   LATITUDE  \
# 904  School of the Art Institute of Chicago     IL      Chicago  41.881050
# 906                       Aurora University     IL       Aurora  41.753631
# 911                       Blackburn College     IL  Carlinville  39.287896
# 914                      Bradley University     IL       Peoria  40.696896
# 928                Chicago State University     IL      Chicago  41.718446
#
#      LONGITUDE  SCHTYPE  C100_4  TRANS_4  SAT_AVG  ACTCMMID  ...  UGDS_MEN  \
# 904 -87.625758      1.0  0.4541   0.1881   1242.0      26.0  ...    0.2471
# 906 -88.349023      1.0  0.3793   0.0000   1062.0      21.0  ...    0.3551
# 911 -89.870241      1.0  0.4539   0.0000   1041.0      21.0  ...    0.4332
# 914 -89.616786      1.0  0.5089   0.0000   1212.0      25.0  ...    0.4939
# 928 -87.609384      0.0  0.0239   0.5047    946.0      19.0  ...    0.3037
#
# ...

# %%
SY17 = pd.read_csv("MERGED2016_17_PP.csv")
# SY17.head()
SY17_IL = SY17.loc[SY17["STABBR"]=="IL"]
# SY17_IL.head()
SY17_IL = SY17_IL[["INSTNM","STABBR","CITY","LATITUDE","LONGITUDE","SCHTYPE","C100_4","TRANS_4","SAT_AVG","ACTCMMID","UGDS","UGDS_WOMEN","UGDS_MEN","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN","TUITIONFEE_IN","TUITIONFEE_OUT","COSTT4_A"]]
SY17_IL["Year"]="2017"
# SY17_IL.head()
# Out:
# C:\Users\koros\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6,1729,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for index, row in SY17_IL.iterrows():
    if row['INSTNM'] in SY19_IL['INSTNM'].tolist():
        latitude = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'LATITUDE'].iloc[0]
        SY17_IL.at[index,'LATITUDE']= latitude
        longitude = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'LONGITUDE'].iloc[0]
        SY17_IL.at[index,'LONGITUDE']= longitude
        school_type = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'SCHTYPE'].iloc[0]
        SY17_IL.at[index,'SCHTYPE']= school_type

SY17_IL = SY17_IL.dropna()
SY17_IL.head()
# Out:
#                                      INSTNM STABBR         CITY   LATITUDE  \
# 923  School of the Art Institute of Chicago     IL      Chicago  41.881050
# 925                       Aurora University     IL       Aurora  41.753631
# 930                       Blackburn College     IL  Carlinville  39.287896
# 933                      Bradley University     IL       Peoria  40.696896
# 947                Chicago State University     IL      Chicago  41.718446
#
#      LONGITUDE  SCHTYPE  C100_4  TRANS_4  SAT_AVG  ACTCMMID  ...  UGDS_MEN  \
# 923 -87.625758      1.0  0.4176   0.2141   1127.0      25.0  ...    0.2669
# 925 -88.349023      1.0  0.4137   0.0000   1005.0      22.0  ...    0.3523
# 930 -89.870241      1.0  0.3067   0.0000    968.0      21.0  ...    0.4617
# 933 -89.616786      1.0  0.5414   0.0000   1141.0      25.0  ...    0.4948
# 947 -87.609384      0.0  0.0274   0.4761    883.0      18.0  ...    0.2997
#
# ...

# %%
SY16 = pd.read_csv("MERGED2015_16_PP.csv")
# SY16.head()
SY16_IL = SY16.loc[SY16["STABBR"]=="IL"]
# SY16_IL.head()
SY16_IL = SY16_IL[["INSTNM","STABBR","CITY","LATITUDE","LONGITUDE","SCHTYPE","C100_4","TRANS_4","SAT_AVG","ACTCMMID","UGDS","UGDS_WOMEN","UGDS_MEN","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN","TUITIONFEE_IN","TUITIONFEE_OUT","COSTT4_A"]]
SY16_IL["Year"]="2016"
# SY16_IL.head()

# %%
for index, row in SY16_IL.iterrows():
    if row['INSTNM'] in SY19_IL['INSTNM'].tolist():
        latitude = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'LATITUDE'].iloc[0]
        SY16_IL.at[index,'LATITUDE']= latitude
        longitude = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'LONGITUDE'].iloc[0]
        SY16_IL.at[index,'LONGITUDE']= longitude
        school_type = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'SCHTYPE'].iloc[0]
        SY16_IL.at[index,'SCHTYPE']= school_type

SY16_IL = SY16_IL.dropna()
SY16_IL.head()
# Out:
#                                      INSTNM STABBR         CITY   LATITUDE  \
# 950  School of the Art Institute of Chicago     IL      Chicago  41.881050
# 952                       Aurora University     IL       Aurora  41.753631
# 957                       Blackburn College     IL  Carlinville  39.287896
# 960                      Bradley University     IL       Peoria  40.696896
# 974                Chicago State University     IL      Chicago  41.718446
#
#      LONGITUDE  SCHTYPE  C100_4  TRANS_4  SAT_AVG  ACTCMMID  ...  UGDS_MEN  \
# 950 -87.625758      1.0  0.3814   0.2483   1155.0      25.0  ...    0.2751
# 952 -88.349023      1.0  0.4185   0.0000    990.0      21.0  ...    0.3583
# 957 -89.870241      1.0  0.3151   0.0000   1005.0      22.0  ...    0.4560
# 960 -89.616786      1.0  0.5289   0.0000   1163.0      26.0  ...    0.4908
# 974 -87.609384      0.0  0.0221   0.5382    875.0      18.0  ...    0.2912
#
# ...

# %%
SY15 = pd.read_csv("MERGED2014_15_PP.csv")
# SY15.head()
SY15_IL = SY15.loc[SY15["STABBR"]=="IL"]
# SY15_IL.head()
SY15_IL = SY15_IL[["INSTNM","STABBR","CITY","LATITUDE","LONGITUDE","SCHTYPE","C100_4","TRANS_4","SAT_AVG","ACTCMMID","UGDS","UGDS_WOMEN","UGDS_MEN","UGDS_WHITE","UGDS_BLACK","UGDS_HISP","UGDS_ASIAN","UGDS_AIAN","TUITIONFEE_IN","TUITIONFEE_OUT","COSTT4_A"]]
SY15_IL["Year"]="2015"
# SY15_IL.head()
# Out:
# C:\Users\koros\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6,1537,1540,1542,1589,1606,1610,1614,1615,1729,1909,1910,1911,1912,1913) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
for index, row in SY15_IL.iterrows():
    if row['INSTNM'] in SY19_IL['INSTNM'].tolist():
        latitude = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'LATITUDE'].iloc[0]
        SY15_IL.at[index,'LATITUDE']= latitude
        longitude = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'LONGITUDE'].iloc[0]
        SY15_IL.at[index,'LONGITUDE']= longitude
        school_type = SY19_IL.loc[SY19_IL['INSTNM']==row['INSTNM'], 'SCHTYPE'].iloc[0]
        SY15_IL.at[index,'SCHTYPE']= school_type

SY15_IL = SY15_IL.dropna()
SY15_IL.head()
# Out:
#                                       INSTNM STABBR         CITY   LATITUDE  \
# 995   School of the Art Institute of Chicago     IL      Chicago  41.881050
# 997                        Aurora University     IL       Aurora  41.753631
# 1002                       Blackburn College     IL  Carlinville  39.287896
# 1005                      Bradley University     IL       Peoria  40.696896
# 1019                Chicago State University     IL      Chicago  41.718446
#
#       LONGITUDE  SCHTYPE  C100_4  TRANS_4  SAT_AVG  ACTCMMID  ...  UGDS_MEN  \
# 995  -87.625758      1.0  0.3696     0.22   1065.0      23.0  ...    0.2846
# 997  -88.349023      1.0  0.4350     0.00   1010.0      22.0  ...    0.3335
# 1002 -89.870241      1.0  0.3041     0.00    989.0      21.0  ...    0.4567
# 1005 -89.616786      1.0  0.5078     0.00   1162.0      26.0  ...    0.4862
# 1019 -87.609384      0.0  0.0249     0.50    870.0      18.0  ...    0.2845
#
# ...

# %%
print(f'The length of SY15_IL is {len(SY15_IL)}')
print(f'The length of SY16_IL is {len(SY16_IL)}')
print(f'The length of SY17_IL is {len(SY17_IL)}')
print(f'The length of SY18_IL is {len(SY18_IL)}')
print(f'The length of SY19_IL is {len(SY19_IL)}')
# Out:
# The length of SY15_IL is 47
# The length of SY16_IL is 46
# The length of SY17_IL is 46
# The length of SY18_IL is 48
# The length of SY19_IL is 48

# %%
dfs = [SY19_IL, SY18_IL, SY17_IL, SY16_IL, SY15_IL]
SY2015_2019 = pd.concat(dfs)
SY2015_2019
# Out:
# C:\Users\koros\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#       ACTCMMID  C100_4           CITY  COSTT4_A  \
# 865       25.0  0.4728        Chicago   63848.0
# 867       21.0  0.3718         Aurora   34650.0
# 872       20.0  0.3407    Carlinville   30605.0
# 875       26.0  0.5953         Peoria   46304.0
# 888       18.0  0.0394        Chicago   20357.0
# ...        ...     ...            ...       ...
# 1166      24.0  0.4511  Palos Heights   35139.0
# 1167      23.0  0.3582      Deerfield   39292.0
# 1170      24.0  0.6000        Chicago   35742.0
# 1173      21.0  0.2968         Macomb   25074.0
# 1174      30.0  0.7966        Wheaton   42390.0
#
# ...

# %%
SY15_IL.to_csv("Output/SY15_IL.csv", index=False, header=True)
SY16_IL.to_csv("Output/SY16_IL.csv", index=False, header=True)
SY17_IL.to_csv("Output/SY17_IL.csv", index=False, header=True)
SY18_IL.to_csv("Output/SY18_IL.csv", index=False, header=True)
SY19_IL.to_csv("Output/SY19_IL.csv", index=False, header=True)
SY2015_2019.to_csv("Output/SY2015_2019.csv", index=False, header=True)
